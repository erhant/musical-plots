# %%
import scales
import chords
import notes
from main import circle_of_fifths, hexes_of_tenths, fretboard, piano
# %matplotlib inline

# %%
hexes_of_tenths(halfsteps=scales.Minor, root=notes.Gs)

# %%
circle_of_fifths(root=notes.C)

# %%
fretboard(root=notes.E, halfsteps=chords.Hendrix)

# %%
piano(root=notes.Ab, halfsteps=scales.Major)
